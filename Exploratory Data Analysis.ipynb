# %% [markdown]
# ### IMPORT PACKAGES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
#reading the mathametics subject datasetof student
mat_df = pd.read_csv('student-mat.csv',sep = ";")
mat_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
#reading the portuguese subject dataset of student  
por_df = pd.read_csv('student-por.csv',sep = ";")
por_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
mat_df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
por_df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
mat_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
por_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
mat_df['subject'] = 'mathematics'
por_df['subject'] = 'portuguese'

# %%
#concatenating the datasets of mathematics and portuguese
data_df = pd.concat([mat_df, por_df])

# %%
data_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
data_df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3     subject
# 644  ...        4     2     1     2       5        4  10  11  10  portuguese
# 645  ...        3     4     1     1       1        4  15  15  16  portuguese
# 646  ...        1     1     1     1       5        6  11  12   9  portuguese
# 647  ...        4     5     3     4       2        6  10  10  10  portuguese
# 648  ...        4     1     3     4       5        4  10  11  11  portuguese
#
# [5 rows x 34 columns]

# %%
#Finding the number of columns 
mat_df.shape
# Out:
# (395, 34)

# %%
por_df.shape
# Out:
# (649, 34)

# %%
mat_df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
por_df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
mat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
por_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
#Finding the number of null values in dataset
mat_df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# subject       0
# dtype: int64

# %%
#Finding the number of null values
por_df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# subject       0
# dtype: int64

# %%
plt.figure(figsize=(5,5))

ax = sns.barplot(x='subject', y='G3', hue='sex', data=data_df)

ax.set_xticklabels(('Mathematics', 'Portuguese'))
plt.xlabel('Subject')
plt.ylabel('Final Grade - G3')
plt.title('Comparison of grades between men and women by subject')
# Out:
# Text(0.5, 1.0, 'Comparison of grades between men and women by subject')

# %% [markdown]
# The above graph comapares the  grade G3 of Mathematics and Portuguese Subjects for both men and women .
# We can observe from the graph that for Mathematics Men have high grades and for Portuguese subject Women have High grades

# %%
g = sns.FacetGrid(mat_df, col="studytime")

g.map(sns.countplot, "age")
# Out:
# C:\Users\12499\anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# From the above graph the majority of students are spending time of 2 to 5 hours(study time =2) to study .
# Very Few students are spending 4 to 10 hours(studytime = 4) for studying for Matematics Subject.

# %%
g = sns.FacetGrid(por_df, col="studytime")
g.map(sns.countplot, "age")

# %% [markdown]
# We can observe from the graph that majority of students are spending time of 2 to 5 hours(study time =2) to study .
# Very Few students are spending 4 to 10 hours(studytime = 4) for studying for Portuguese subject Subject.

# %%
g = sns.FacetGrid(mat_df, col="traveltime")
g.map(sns.countplot, "G3")

# %% [markdown]
# From the above graph we can observe that most of students having higher Grades have travel time < 15 min(traveltime=1).
# students having lower Grades have travel time greater than 1 hour(traveltime=4) for mathematics subject.

# %%
g = sns.FacetGrid(mat_df, col="traveltime")
g.map(sns.countplot, "G3")

# %% [markdown]
# we can observe that most of students having high Grades have travel time < 15 min(traveltime=1).
# students having lower Grades have travel time greater than 1 hour(traveltime=4) fo Portuguese subject.

# %%
b = sns.countplot(mat_df['G3'])
b.axes.set_title('Distribution of Final grade of Mathematics Subject', fontsize = 25)
b.set_xlabel('Final Grade', fontsize = 20)
b.set_ylabel('Count', fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-84d4b5497f1a> in <module>
# ----> 1 b = sns.countplot(mat_df['G3'])
#       2 b.axes.set_title('Distribution of Final grade of Mathematics Subject', fontsize = 25)
#       3 b.set_xlabel('Final Grade', fontsize = 20)
#       4 b.set_ylabel('Count', fontsize = 20)
#       5 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# The above plot gives the distribution of Grade G3 of students . Most of the students have a Grade of 10 and
# Very few students have a Grade 20 for Mathematics subject

# %%
b = sns.countplot(por_df['G3'])
b.axes.set_title('Distribution of Final grade of students of Portuguese', fontsize = 25)
b.set_xlabel('Final Grade', fontsize = 20)
b.set_ylabel('Count', fontsize = 20)
plt.show()

# %% [markdown]
# The above plot gives the distribution of Grade G3 of students . Majority of the students have a Grade of 11 and
# Very few students have a Grade 19 for Portuguese subject

# %%
sns.boxplot(x='studytime', y='G3', data=mat_df)

plt.xlabel('Study Time')
plt.ylabel('Final Grade - G3')
plt.title('Final Grades by Study Time For Mathematics Subject')
# Out:
# Text(0.5, 1.0, 'Final Grades by Study Time For Mathematics Subject')

# %% [markdown]
# The above Box plot shows that the students having study time =4 have the highest grades .
# The students having study time =2 have low grades for Mathematics Subject

# %%
sns.boxplot(x='studytime', y='G3', data=por_df)

plt.xlabel('Study Time')
plt.ylabel('Final Grade - G3')
plt.title('Final Grades by Study Time For Portuguese Subject')
# Out:
# Text(0.5, 1.0, 'Final Grades by Study Time For Portuguese Subject')

# %% [markdown]
# The above Box plot shows that the students having study time =2 and 4 have the highest grades .
# The students having study time =1 have low grades for Portuguese Subject

# %%
#mother's job plot
p=sns.countplot('Mjob',data=mat_df)
p.axes.set_title('Mothers Job Of Mathematics subject Students ', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Mothers Job Of Mathematics subject Students ')

# %% [markdown]
# We can observe from the graph that nearly 140 students have mothers working in other jobs .
# Few students have mothers working in Health Department

# %%
#mother's job plot
p=sns.countplot('Mjob',data=por_df)
p.axes.set_title('Mothers Job Of Portuguese Subject Students', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Mothers Job Of Portuguese Subject Students')

# %% [markdown]
# We can observe from the graph that nearly 250 students have mothers working in other jobs . Few students have mothers working in Health Department

# %%
b = sns.swarmplot(x='G1', y='G3', data=mat_df)
b.axes.set_title('G1 vs G3 For Mathematics Subject', fontsize = 30)
b.set_xlabel('G1', fontsize = 20)
b.set_ylabel('G3', fontsize = 20)
plt.show()

# %% [markdown]
# The graph shows that the students scored high G1 has high G3 .

# %%
b = sns.swarmplot(x='G1', y='G3', data=mat_df)
b.axes.set_title('G1 vs G3 For Portuguese Subject', fontsize = 30)
b.set_xlabel('G1', fontsize = 20)
b.set_ylabel('G3', fontsize = 20)
plt.show()

# %% [markdown]
# The graph shows that the students scored high G1 has high G3 For Portuguese Subject .

# %%
b = sns.swarmplot(x='G2', y='G3', data=mat_df)
b.axes.set_title('G2 vs G3 For Mathematics Subject', fontsize = 30)
b.set_xlabel('G2', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()

# %% [markdown]
# We can observe from the plot that both G2 and G3 are directly proportional to each other.

# %%
b = sns.swarmplot(x='G2', y='G3', data=por_df)
b.axes.set_title('G2 vs G3 For Portuguese Subject', fontsize = 30)
b.set_xlabel('G2', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()

# %% [markdown]
# The above graph shows that higher G2 students has higher G3 and lower G2 students has lower G2

# %%
corr = mat_df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr, cmap = 'coolwarm', annot = True)
plt.title('Correlation Matrix Of Mathematics Subject', fontsize=10);

# %% [markdown]
# From the above correlation matrix we can observe that there is strong correlation between G1,G2 and G3 for Mathematics Subject

# %%
corr = por_df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr, cmap = 'coolwarm', annot = True)
plt.title('Correlation Matrix Of Portuguese Subject', fontsize=10);

# %% [markdown]
# From the above correlation matrix we can observe that there is strong correlation between G1,G2 and G3 for Portuguese Subject

# %%
plt.figure(figsize=(5,5))

ax = sns.barplot(x='Fedu', y='G3', data=mat_df)


plt.xlabel('Fedu')
plt.ylabel('Final Grade - G3')
plt.title('RelationShip Between Fathers Education and G3 For Mathematics Subject')
# Out:
# Text(0.5, 1.0, 'RelationShip Between Fathers Education and G3 For Mathematics Subject')

# %% [markdown]
# The above graph gives the relation between Fathers Education and Grade G3 of Student .
# The students having fathers education as 0 which is no education have highest grades and
# the students have fathers education as 1 have low grades for Mathematics subject.

# %%
plt.figure(figsize=(5,5))

ax = sns.barplot(x='Fedu', y='G3', data=por_df)


plt.xlabel('Fedu')
plt.ylabel('Final Grade - G3')
plt.title('RelationShip Between Fathers Education and G3 For portuguese Subject')
# Out:
# Text(0.5, 1.0, 'RelationShip Between Fathers Education and G3 For portuguese Subject')

# %% [markdown]
# The above graph gives the relation between Fathers Education and Grade of Student .
# The students having fathers education as 4 which is higher education have highest grades and
# the students have fathers education as 1 have low grades for portuguese subject.
